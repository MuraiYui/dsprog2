# %%
import flet as ft


class CalcButton(ft.ElevatedButton):
    def __init__(self, text, expand=1):
        super().__init__()
        self.text = text
        self.expand = expand


class DigitButton(CalcButton):
    def __init__(self, text, expand=1):
        CalcButton.__init__(self, text, expand)
        self.bgcolor = ft.Colors.WHITE24
        self.color = ft.Colors.WHITE


class ActionButton(CalcButton):
    def __init__(self, text):
        CalcButton.__init__(self, text)
        self.bgcolor = ft.Colors.ORANGE
        self.color = ft.Colors.WHITE


class ExtraActionButton(CalcButton):
    def __init__(self, text):
        CalcButton.__init__(self, text)
        self.bgcolor = ft.Colors.BLUE_GREY_100
        self.color = ft.Colors.BLACK


def main(page: ft.Page):
    page.title = "Simple Calculator"
    result = ft.Text(value="0", color=ft.Colors.WHITE, size=20)

    page.add(
        ft.Container(
            width=350,
            bgcolor=ft.Colors.BLACK,
            border_radius=ft.border_radius.all(20),
            padding=20,
            content=ft.Column(
                controls=[
                    ft.Row(controls=[result]),
                    ft.Row(
                        controls=[
                            ExtraActionButton(text="AC"),
                            ExtraActionButton(text="+/-"),
                            ExtraActionButton(text="%"),
                            ActionButton(text="/"),
                        ]
                    ),
                    ft.Row(
                        controls=[
                            DigitButton(text="7"),
                            DigitButton(text="8"),
                            DigitButton(text="9"),
                            ActionButton(text="*"),
                        ]
                    ),
                    ft.Row(
                        controls=[
                            DigitButton(text="4"),
                            DigitButton(text="5"),
                            DigitButton(text="6"),
                            ActionButton(text="-"),
                        ]
                    ),
                    ft.Row(
                        controls=[
                            DigitButton(text="1"),
                            DigitButton(text="2"),
                            DigitButton(text="3"),
                            ActionButton(text="+"),
                        ]
                    ),
                    ft.Row(
                        controls=[
                            DigitButton(text="0", expand=2),
                            DigitButton(text="."),
                            ActionButton(text="="),
                        ]
                    ),
                ]
            ),
        )
    )


ft.app(main)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 90
#      34     result = ft.Text(value="0", color=ft.Colors.WHITE, size=20)
#      36     page.add(
#      37         ft.Container(
#      38             width=350,
#    (...)     86         )
#      87     )
# ---> 90 ft.app(main)
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/site-packages/flet/app.py:64, in app(target, name, host, port, view, assets_dir, upload_dir, web_renderer, use_color_emoji, route_url_strategy, export_asgi_app)
#      52     from flet_web.fastapi.serve_fastapi_web_app import get_fastapi_web_app
#      54     return get_fastapi_web_app(
#      55         session_handler=target,
#      56         page_name=__get_page_name(name),
#    (...)     61         route_url_strategy=route_url_strategy,
#      62     )
# ---> 64 return asyncio.run(
#      65     app_async(
#      66         target=target,
#      67         name=name,
#      68         host=host,
#      69         port=port,
#      70         view=view,
#      71         assets_dir=assets_dir,
#      72         upload_dir=upload_dir,
#      73         web_renderer=web_renderer,
#      74         use_color_emoji=use_color_emoji,
#      75         route_url_strategy=route_url_strategy,
#      76     )
#      77 )
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import flet as ft


class CalcButton(ft.ElevatedButton):
    def __init__(self, text, button_clicked, expand=1):
        super().__init__()
        self.text = text
        self.expand = expand
        self.on_click = button_clicked
        self.data = text


class DigitButton(CalcButton):
    def __init__(self, text, button_clicked, expand=1):
        CalcButton.__init__(self, text, button_clicked, expand)
        self.bgcolor = ft.Colors.WHITE24
        self.color = ft.Colors.WHITE


class ActionButton(CalcButton):
    def __init__(self, text, button_clicked):
        CalcButton.__init__(self, text, button_clicked)
        self.bgcolor = ft.Colors.ORANGE
        self.color = ft.Colors.WHITE


class ExtraActionButton(CalcButton):
    def __init__(self, text, button_clicked):
        CalcButton.__init__(self, text, button_clicked)
        self.bgcolor = ft.Colors.BLUE_GREY_100
        self.color = ft.Colors.BLACK


class CalculatorApp(ft.Container):
    def __init__(self):
        super().__init__()
        self.reset()

        self.result = ft.Text(value="0", color=ft.Colors.WHITE, size=20)
        self.width = 350
        self.bgcolor = ft.Colors.BLACK
        self.border_radius = ft.border_radius.all(20)
        self.padding = 20
        self.content = ft.Column(
            controls=[
                ft.Row(controls=[self.result], alignment="end"),
                ft.Row(
                    controls=[
                        ExtraActionButton(text="AC", button_clicked=self.button_clicked),
                        ExtraActionButton(text="+/-", button_clicked=self.button_clicked),
                        ExtraActionButton(text="%", button_clicked=self.button_clicked),
                        ActionButton(text="/", button_clicked=self.button_clicked),
                    ]
                ),
                ft.Row(
                    controls=[
                        DigitButton(text="7", button_clicked=self.button_clicked),
                        DigitButton(text="8", button_clicked=self.button_clicked),
                        DigitButton(text="9", button_clicked=self.button_clicked),
                        ActionButton(text="*", button_clicked=self.button_clicked),
                    ]
                ),
                ft.Row(
                    controls=[
                        DigitButton(text="4", button_clicked=self.button_clicked),
                        DigitButton(text="5", button_clicked=self.button_clicked),
                        DigitButton(text="6", button_clicked=self.button_clicked),
                        ActionButton(text="-", button_clicked=self.button_clicked),
                    ]
                ),
                ft.Row(
                    controls=[
                        DigitButton(text="1", button_clicked=self.button_clicked),
                        DigitButton(text="2", button_clicked=self.button_clicked),
                        DigitButton(text="3", button_clicked=self.button_clicked),
                        ActionButton(text="+", button_clicked=self.button_clicked),
                    ]
                ),
                ft.Row(
                    controls=[
                        DigitButton(text="0", expand=2, button_clicked=self.button_clicked),
                        DigitButton(text=".", button_clicked=self.button_clicked),
                        ActionButton(text="=", button_clicked=self.button_clicked),
                    ]
                ),
            ]
        )

    def button_clicked(self, e):
        data = e.control.data
        print(f"Button clicked with data = {data}")
        if self.result.value == "Error" or data == "AC":
            self.result.value = "0"
            self.reset()

        elif data in ("1", "2", "3", "4", "5", "6", "7", "8", "9", "0", "."):
            if self.result.value == "0" or self.new_operand == True:
                self.result.value = data
                self.new_operand = False
            else:
                self.result.value = self.result.value + data

        elif data in ("+", "-", "*", "/"):
            self.result.value = self.calculate(self.operand1, float(self.result.value), self.operator)
            self.operator = data
            if self.result.value == "Error":
                self.operand1 = "0"
            else:
                self.operand1 = float(self.result.value)
            self.new_operand = True

        elif data in ("="):
            self.result.value = self.calculate(self.operand1, float(self.result.value), self.operator)
            self.reset()

        elif data in ("%"):
            self.result.value = float(self.result.value) / 100
            self.reset()

        elif data in ("+/-"):
            if float(self.result.value) > 0:
                self.result.value = "-" + str(self.result.value)

            elif float(self.result.value) < 0:
                self.result.value = str(self.format_number(abs(float(self.result.value))))

        self.update()

    def format_number(self, num):
        if num % 1 == 0:
            return int(num)
        else:
            return num

    def calculate(self, operand1, operand2, operator):

        if operator == "+":
            return self.format_number(operand1 + operand2)

        elif operator == "-":
            return self.format_number(operand1 - operand2)

        elif operator == "*":
            return self.format_number(operand1 * operand2)

        elif operator == "/":
            if operand2 == 0:
                return "Error"
            else:
                return self.format_number(operand1 / operand2)

    def reset(self):
        self.operator = "+"
        self.operand1 = 0
        self.new_operand = True



def main(page: ft.Page):
    page.title = "Simple Calculator"
    # ページ設定を追加して電卓らしく見せることができます (任意)
    page.window_width = 370
    page.window_height = 550
    page.window_resizable = False
    
    calc = CalculatorApp()
    page.add(calc)

# 🚨 この行を修正します
ft.app_process(main, view=ft.AppView.WEB_BROWSER)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 170
#     167     page.add(calc)
#     169 # 🚨 この行を修正します
# --> 170 ft.app_process(main, view=ft.AppView.WEB_BROWSER)
#
# AttributeError: module 'flet' has no attribute 'app_process'

# %%
import flet as ft


class CalcButton(ft.ElevatedButton):
    def __init__(self, text, button_clicked, expand=1):
        super().__init__()
        self.text = text
        self.expand = expand
        self.on_click = button_clicked
        self.data = text


class DigitButton(CalcButton):
    def __init__(self, text, button_clicked, expand=1):
        CalcButton.__init__(self, text, button_clicked, expand)
        self.bgcolor = ft.Colors.WHITE24
        self.color = ft.Colors.WHITE


class ActionButton(CalcButton):
    def __init__(self, text, button_clicked):
        CalcButton.__init__(self, text, button_clicked)
        self.bgcolor = ft.Colors.ORANGE
        self.color = ft.Colors.WHITE


class ExtraActionButton(CalcButton):
    def __init__(self, text, button_clicked):
        CalcButton.__init__(self, text, button_clicked)
        self.bgcolor = ft.Colors.BLUE_GREY_100
        self.color = ft.Colors.BLACK


class CalculatorApp(ft.Container):
    def __init__(self):
        super().__init__()
        self.reset()

        self.result = ft.Text(value="0", color=ft.Colors.WHITE, size=20)
        self.width = 350
        self.bgcolor = ft.Colors.BLACK
        self.border_radius = ft.border_radius.all(20)
        self.padding = 20
        self.content = ft.Column(
            controls=[
                ft.Row(controls=[self.result], alignment="end"),
                ft.Row(
                    controls=[
                        ExtraActionButton(text="AC", button_clicked=self.button_clicked),
                        ExtraActionButton(text="+/-", button_clicked=self.button_clicked),
                        ExtraActionButton(text="%", button_clicked=self.button_clicked),
                        ActionButton(text="/", button_clicked=self.button_clicked),
                    ]
                ),
                ft.Row(
                    controls=[
                        DigitButton(text="7", button_clicked=self.button_clicked),
                        DigitButton(text="8", button_clicked=self.button_clicked),
                        DigitButton(text="9", button_clicked=self.button_clicked),
                        ActionButton(text="*", button_clicked=self.button_clicked),
                    ]
                ),
                ft.Row(
                    controls=[
                        DigitButton(text="4", button_clicked=self.button_clicked),
                        DigitButton(text="5", button_clicked=self.button_clicked),
                        DigitButton(text="6", button_clicked=self.button_clicked),
                        ActionButton(text="-", button_clicked=self.button_clicked),
                    ]
                ),
                ft.Row(
                    controls=[
                        DigitButton(text="1", button_clicked=self.button_clicked),
                        DigitButton(text="2", button_clicked=self.button_clicked),
                        DigitButton(text="3", button_clicked=self.button_clicked),
                        ActionButton(text="+", button_clicked=self.button_clicked),
                    ]
                ),
                ft.Row(
                    controls=[
                        DigitButton(text="0", expand=2, button_clicked=self.button_clicked),
                        DigitButton(text=".", button_clicked=self.button_clicked),
                        ActionButton(text="=", button_clicked=self.button_clicked),
                    ]
                ),
            ]
        )

    def button_clicked(self, e):
        data = e.control.data
        print(f"Button clicked with data = {data}")
        if self.result.value == "Error" or data == "AC":
            self.result.value = "0"
            self.reset()

        elif data in ("1", "2", "3", "4", "5", "6", "7", "8", "9", "0", "."):
            if self.result.value == "0" or self.new_operand == True:
                self.result.value = data
                self.new_operand = False
            else:
                self.result.value = self.result.value + data

        elif data in ("+", "-", "*", "/"):
            # 演算子ボタンを押すたびに中間結果を計算
            self.result.value = self.calculate(self.operand1, float(self.result.value), self.operator)
            self.operator = data
            if self.result.value == "Error":
                self.operand1 = 0 # エラー時はオペランドをリセット
            else:
                self.operand1 = float(self.result.value)
            self.new_operand = True

        elif data in ("="):
            # 最終的な計算を実行
            self.result.value = self.calculate(self.operand1, float(self.result.value), self.operator)
            # 計算後の状態をリセットし、次の演算に備える
            if self.result.value != "Error":
                self.reset()
                self.operand1 = float(self.result.value) # 結果を次の計算の第一オペランドにする
                self.new_operand = True # 次の数字入力で画面をクリアする
            
        elif data in ("%"):
            # 0で割り算のエラーチェックは不要だが、format_numberのためにfloat化
            current_value = float(self.result.value)
            self.result.value = self.format_number(current_value / 100)
            self.new_operand = True # 結果を表示したら、次の入力でクリア

        elif data in ("+/-"):
            current_value = float(self.result.value)
            if current_value != 0:
                self.result.value = self.format_number(-current_value)
            self.new_operand = False # 符号変更は入力途中とみなす

        self.update()

    def format_number(self, num):
        # FletのTextコントロールは文字列を受け取るので、ここではstr()を返す
        if abs(num) % 1 == 0:
            return str(int(num))
        else:
            return str(num)

    def calculate(self, operand1, operand2, operator):

        if operator == "+":
            return self.format_number(operand1 + operand2)

        elif operator == "-":
            return self.format_number(operand1 - operand2)

        elif operator == "*":
            return self.format_number(operand1 * operand2)

        elif operator == "/":
            if operand2 == 0:
                return "Error"
            else:
                return self.format_number(operand1 / operand2)

    def reset(self):
        # リセット時、次の演算のために初期値を設定
        self.operator = "+"
        self.operand1 = 0
        self.new_operand = True


def main(page: ft.Page):
    page.title = "Simple Calculator"
    # ページを小さくして電卓らしく見せる
    page.window_width = 370
    page.window_height = 550
    page.window_resizable = False
    
    calc = CalculatorApp()
    page.add(calc)


# 🚨 変更箇所: ft.app() の代わりに ft.app_process() を使用
ft.app_process(main, view=ft.AppView.WEB_BROWSER) # ブラウザ表示の場合
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 179
#     175     page.add(calc)
#     178 # 🚨 変更箇所: ft.app() の代わりに ft.app_process() を使用
# --> 179 ft.app_process(main, view=ft.AppView.WEB_BROWSER) # ブラウザ表示の場合
#
# AttributeError: module 'flet' has no attribute 'app_process'

# %%
import flet
print(f"Flet version being used: {flet.__version__}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import flet
# ----> 2 print(f"Flet version being used: {flet.__version__}")
#
# AttributeError: module 'flet' has no attribute '__version__'

# %%
import flet as ft


class CalcButton(ft.ElevatedButton):
# ... (中略：クラス定義) ...
# ... (中略：CalculatorAppクラスの定義とメソッド) ...
# ...
    def reset(self):
        self.operator = "+"
        self.operand1 = 0
        self.new_operand = True


def main(page: ft.Page):
    page.title = "Simple Calculator"
    # ページサイズを電卓用に設定 (必須ではありませんが推奨)
    page.window_width = 370
    page.window_height = 550
    page.window_resizable = False 
    
    calc = CalculatorApp()
    page.add(calc)


# 🚨 Jupyter/Colab/VS Code .ipynb 環境での正しい実行方法
ft.app_process(main, view=ft.AppView.WEB_BROWSER)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 26
#      22     page.add(calc)
#      25 # 🚨 Jupyter/Colab/VS Code .ipynb 環境での正しい実行方法
# ---> 26 ft.app_process(main, view=ft.AppView.WEB_BROWSER)
#
# AttributeError: module 'flet' has no attribute 'app_process'

# %%
# !pip install flet-components
# Out:
# Collecting flet-components
#   Downloading flet_components-0.0.9-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: flet>=0.25.2 in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from flet-components) (0.28.3)
# Requirement already satisfied: httpx in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from flet>=0.25.2->flet-components) (0.28.1)
# Requirement already satisfied: oauthlib<4.0.0,>=3.2.2 in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from flet>=0.25.2->flet-components) (3.3.1)
# Requirement already satisfied: repath<0.10.0,>=0.9.0 in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from flet>=0.25.2->flet-components) (0.9.0)
# Requirement already satisfied: six>=1.9.0 in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from repath<0.10.0,>=0.9.0->flet>=0.25.2->flet-components) (1.17.0)
# Requirement already satisfied: anyio in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from httpx->flet>=0.25.2->flet-components) (4.9.0)
# Requirement already satisfied: certifi in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from httpx->flet>=0.25.2->flet-components) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from httpx->flet>=0.25.2->flet-components) (1.0.9)
# Requirement already satisfied: idna in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from httpx->flet>=0.25.2->flet-components) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from httpcore==1.*->httpx->flet>=0.25.2->flet-components) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from anyio->httpx->flet>=0.25.2->flet-components) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /Users/yuimurai/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from anyio->httpx->flet>=0.25.2->flet-components) (4.15.0)
# Downloading flet_components-0.0.9-py3-none-any.whl (18 kB)
# Installing collected packages: flet-components
# Successfully installed flet-components-0.0.9
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
